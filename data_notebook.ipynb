# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import time
from scipy.stats import linregress
import seaborn as sns

# %%
csv = "Resources/cities.csv"

# %%
data_cities = pd.read_csv(csv)
data_cities.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
html = data_cities.to_html()
text_file = open("Resources/data_cities.html", "w")
text_file.write(html)
text_file.close()
plt.scatter(data_cities['Lat'],
            data_cities['Max Temp'],
            alpha=0.75,
            edgecolors='orange', linewidths=1, marker="o",)
plt.title('City Latitude vs. Max Temperature (%s)' % time.strftime('%x'))
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)
sns.set()

plt.savefig("assets/images/Lat_Temp.png")

plt.show()

# %%
plt.scatter(data_cities['Lat'],
            data_cities['Humidity'],
            alpha=0.75,
            edgecolors='blue', linewidths=1, marker="o",)

plt.title('City Latitude vs. Humidity (%s)' % time.strftime('%x'))
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid(True)
sns.set()

plt.savefig("assets/images/Lat_Humidity.png")

plt.show()

# %%
plt.scatter(data_cities['Lat'], 
            data_cities['Cloudiness'], 
            alpha = 0.75, 
            edgecolors = 'red', linewidths=1, marker="o",)

plt.title('City Latitude vs. Cloudiness (%s)' % time.strftime('%x'))
plt.xlabel('Latitude') 
plt.ylabel('Cloudiness')
plt.grid(True)
sns.set()

plt.savefig("assets/images/Lat_Clouds.png")

plt.show()

# %%
plt.scatter(data_cities['Lat'], 
            data_cities['Wind Speed'], 
            alpha = 0.75, 
            edgecolors = 'green', linewidths=1, marker="o",)

plt.title('City Latitude vs. Wind Speed (%s)' % time.strftime('%x'))
plt.xlabel('Latitude') 
plt.ylabel('Wind Speed')
plt.grid(True)
sns.set()

plt.savefig("assets/images/Lat_Winds.png")

plt.show()
